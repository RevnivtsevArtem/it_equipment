# %% [markdown]
# # Model Training
#
# Самодостаточный ноутбук без импортов из src.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1 reopening import f1_score

# %%
def clean_dataset(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df = df.dropna()
    return df

# %%
def build_logistic_regression():
    return LogisticRegression(max_iter=1000)

def build_knn():
    return KNeighborsClassifier(n_neighbors=5)

def build_random_forest():
    return RandomForestClassifier(n_estimators=200, random_state=42)

def build_gradient_boosting():
    return GradientBoostingClassifier(random_state=42)

def build_extra_trees():
    return ExtraTreesClassifier(n_estimators=300, random_state=42)

def build_mlp_sklearn():
    return MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)

# %%
def evaluate_binary_classifier(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return {
        'accuracy': accuracy_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred)
    }

# %%
DATA_PATH = 'data/sample_tickets.csv'
TARGET = 'needs_upgrade'

df = pd.read_csv(DATA_PATH)
df = clean_dataset(df)

X = df.drop(columns=[TARGET])
y = df[TARGET]

cat_cols = X.select_dtypes(include=['object']).columns.tolist()
num_cols = X.select_dtypes(exclude=['object']).columns.tolist()

preprocess = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model = Pipeline([
    ('prep', preprocess),
    ('clf', build_logistic_regression())
])

evaluate_binary_classifier(model, X_train, X_test, y_train, y_test)
